# %% [markdown]
# # Visualize gSparse's Dumbell Graph with Networkx package

# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## A 60 vertices Dumbell

# %%
# Out:
# {}

# %%
H = nx.read_edgelist(path="../Dataset/dumbell-30.csv", delimiter=' ', nodetype=int, encoding="utf-8")
fig = plt.figure(figsize=(10,10))
pos = nx.spring_layout(H,scale=3.0)
nx.draw(H,pos=pos)

nx.node_attribute_xy
plt.show()
fig.savefig("D-1.pdf")

# %% [markdown]
# ## A Sparsifier with Epsilon = 0.25

# %%
allFiles = ['../Dataset/sparsifier-dumbell-eps25-edges.csv',
            '../Dataset/sparsifier-dumbell-eps25-weights.csv']

nodes = np.loadtxt(allFiles[0],delimiter=",")
weight = np.loadtxt(allFiles[1],delimiter=",")
dataset = pd.DataFrame({'source':nodes[:,0],'target':nodes[:,1],'weight':weight})


H=nx.from_pandas_edgelist(dataset, edge_attr=True)
edgewidth = np.array([ float(d['weight']) for (u,v,d) in H.edges(data=True)])

edgewidth = edgewidth * 0.2

fig = plt.figure(figsize=(10,10))
nx.draw(H,pos=pos,width=edgewidth)
plt.show()
fig.savefig("D-2.pdf")

# %% [markdown]
# ## A Sparsifier with Epsilon = 0.50

# %%
allFiles = ['../Dataset/sparsifier-dumbell-eps50-edges.csv',
            '../Dataset/sparsifier-dumbell-eps50-weights.csv']

nodes = np.loadtxt(allFiles[0],delimiter=",")
weight = np.loadtxt(allFiles[1],delimiter=",")
dataset = pd.DataFrame({'source':nodes[:,0],'target':nodes[:,1],'weight':weight})


H=nx.from_pandas_edgelist(dataset, edge_attr=True)
edgewidth = np.array([ float(d['weight']) for (u,v,d) in H.edges(data=True)])

edgewidth = edgewidth * 0.5

fig = plt.figure(figsize=(10,10))
nx.draw(H,pos=pos,width=edgewidth)
plt.show()
fig.savefig("D-3.pdf")

# %% [markdown]
# ## A Sparsifier with Epsilon = 0.75

# %%
allFiles = ['../Dataset/sparsifier-dumbell-eps75-edges.csv',
            '../Dataset/sparsifier-dumbell-eps75-weights.csv']

nodes = np.loadtxt(allFiles[0],delimiter=",")
weight = np.loadtxt(allFiles[1],delimiter=",")
dataset = pd.DataFrame({'source':nodes[:,0],'target':nodes[:,1],'weight':weight})


H=nx.from_pandas_edgelist(dataset, edge_attr=True)
edgewidth = np.array([ float(d['weight']) for (u,v,d) in H.edges(data=True)])

edgewidth = edgewidth  * 0.8

fig = plt.figure(figsize=(10,10))
nx.draw(H,pos=pos,width=edgewidth)
plt.show()
fig.savefig("D-4.pdf")
