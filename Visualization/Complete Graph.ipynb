# %% [markdown]
# # Visualize gSparse's Complete Graph with Networkx package

# %%
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## A 30 vertices completed graph

# %%
H = nx.read_edgelist(path="../Dataset/Complete-30.csv", delimiter=' ', nodetype=int, encoding="utf-8")
fig = plt.figure(figsize=(10,10))
nx.draw(H,pos=nx.circular_layout(H))
plt.show()
fig.savefig("C-1.pdf")

# %% [markdown]
# ## A Sparsifier with Epsilon = 0.25

# %%
allFiles = ['../Dataset/sparsifier-Complete-eps25-edges.csv',
            '../Dataset/sparsifier-Complete-eps25-weights.csv']

nodes = np.loadtxt(allFiles[0],delimiter=",")
weight = np.loadtxt(allFiles[1],delimiter=",")
dataset = pd.DataFrame({'source':nodes[:,0],'target':nodes[:,1],'weight':weight})


H=nx.from_pandas_edgelist(dataset, edge_attr=True)
edgewidth = np.array([ float(d['weight']) for (u,v,d) in H.edges(data=True)])

edgewidth = edgewidth * 0.25

fig = plt.figure(figsize=(10,10))
nx.draw(H,pos=nx.circular_layout(H),width=edgewidth)
plt.show()
fig.savefig("C-2.pdf")

# %% [markdown]
# ## A Sparsifier with Epsilon = 0.50

# %%
allFiles = ['../Dataset/sparsifier-Complete-eps50-edges.csv',
            '../Dataset/sparsifier-Complete-eps50-weights.csv']

nodes = np.loadtxt(allFiles[0],delimiter=",")
weight = np.loadtxt(allFiles[1],delimiter=",")
dataset = pd.DataFrame({'source':nodes[:,0],'target':nodes[:,1],'weight':weight})


H=nx.from_pandas_edgelist(dataset, edge_attr=True)
edgewidth = np.array([ float(d['weight']) for (u,v,d) in H.edges(data=True)])

edgewidth = edgewidth 

fig = plt.figure(figsize=(10,10))
nx.draw(H,pos=nx.circular_layout(H),width=edgewidth)
plt.show()
fig.savefig("C-3.pdf")

# %% [markdown]
# ## A Sparsifier with Epsilon = 0.75

# %%
allFiles = ['../Dataset/sparsifier-Complete-eps75-edges.csv',
            '../Dataset/sparsifier-Complete-eps75-weights.csv']

nodes = np.loadtxt(allFiles[0],delimiter=",")
weight = np.loadtxt(allFiles[1],delimiter=",")
dataset = pd.DataFrame({'source':nodes[:,0],'target':nodes[:,1],'weight':weight})


H=nx.from_pandas_edgelist(dataset, edge_attr=True)
edgewidth = np.array([ float(d['weight']) for (u,v,d) in H.edges(data=True)])

edgewidth = edgewidth

fig = plt.figure(figsize=(10,10))
nx.draw(H,pos=nx.circular_layout(H),width=edgewidth)
plt.show()
fig.savefig("C-4.pdf")
